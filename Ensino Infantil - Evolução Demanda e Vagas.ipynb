# %% [markdown]
# # Censo Escolar
#
# ## Demanda - Evolução

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# mapas
import geojson
import jenkspy

# %% [markdown]
# ### Importar dados

# %%
censo_df = pd.read_csv('dados/evolucao_demanda/evolucaodemanda_0318.csv',
                       encoding='latin-1', sep=';')

# %%
censo_df.columns
# Out:
# Index(['DISTRITO', 'MAT_CRECHE', 'MAT_PRE_ESCOLA', 'MAT_FUND_I', 'MAT_FUND_II',
#        'MAT_EJA_I', 'MAT_EJA_II', 'MAT_ENS_MED', 'MAT_ED_PROF',
#        'MAT_PROC_CRECHE', 'MAT_PROC_PRE_ESC', 'DEM_CRECHE', 'DEM_PRE',
#        'DEM_FUND_I', 'DEM_FUND_II', 'DEM_EJA_I', 'DEM_EJA_II',
#        'DEM_PREF_CRECHE', 'DEM_PREF_PRE', 'MES_ANO_REF'],
#       dtype='object')

# %% [markdown]
# ### Substituir abreviação dos meses por números

# %%
censo_df['MES_ANO_REF'] = censo_df['MES_ANO_REF'].replace({ 'jun' : '06', 'dez' : '12', 'mar' : '03', 'set': '09', '-': '/20' }, regex=True)

# %% [markdown]
# ### Criar coluna para meses

# %%
censo_df['month'] = censo_df['MES_ANO_REF'].str.slice(0,2)

# %% [markdown]
# ### Criar coluna para datas

# %%
censo_df['date'] = pd.to_datetime(censo_df['MES_ANO_REF'], format='%m/%Y', errors='coerce')

# %% [markdown]
# ### Criar colunas para total das matrículas e demanda
#
# É preciso considerar as matrículas em processo e a demanda preferencial.

# %%
# substituindo NaN por zeros
censo_df = censo_df.fillna(value=0)

# %%
censo_df['mat_creche_tot'] = censo_df['MAT_CRECHE'] + censo_df['MAT_PROC_CRECHE']
censo_df['mat_pre_tot'] = censo_df['MAT_PRE_ESCOLA'] + censo_df['MAT_PROC_PRE_ESC']
censo_df['dem_creche_tot'] = censo_df['DEM_CRECHE'] + censo_df['DEM_PREF_CRECHE']
censo_df['dem_pre_tot'] = censo_df['DEM_PRE'] + censo_df['DEM_PREF_PRE']

# %% [markdown]
# ### Filtrar somente mês de dezembro
#
# Uma vez que as estatísticas de demanda da SME são sempre calculadas baseadas em dezembro.

# %%
censo_df[censo_df['month'] == '12']
# Out:
#                 DISTRITO  MAT_CRECHE  MAT_PRE_ESCOLA  MAT_FUND_I  MAT_FUND_II  \
# 192            AGUA RASA         634            1950        1323         1354
# 193    ALTO DE PINHEIROS         248             198           0            0
# 194           ANHANGUERA         247            1974        2944         2549
# 195           ARICANDUVA         460            1716        2354         2082
# 196          ARTUR ALVIM         854            4405        3162         2684
# 197          BARRA FUNDA         259             347           0            0
# 198           BELA VISTA         605            1226         526          497
# 199                BELEM         201            1540         397            0
# 200           BOM RETIRO         472            1602           0            0
# 201                 BRAS         307             690           0            0
# 202          BRASILANDIA        1777            8647        9635         7156
# 203              BUTANTA         241            1617        1595         1485
# 204         CACHOEIRINHA         738            4343        3396         2921
# 205              CAMBUCI         132             809           0            0
# 206           CAMPO BELO         416             847        1395         1286
# 207         CAMPO GRANDE         296            2408        3398         3223
# 208          CAMPO LIMPO        1258            9458        8768         8098
# 209             CANGAIBA         768            4648        2711         2324
# 2012-12-01        214095.0     183262.0         97160.0       2585.0
# 2013-12-01        214460.0     200371.0         96696.0       9688.0
# 2014-12-01        228204.0     202297.0         94191.0       5625.0
# 2015-12-01        260806.0     204551.0         75194.0       3595.0
# 2016-12-01        284217.0     215090.0         65040.0       1269.0
# 2017-12-01        310276.0     219359.0         44092.0          0.0

# %%
evol_ens_inf_df.plot.line()
plt.show()

# %% [markdown]
# ### Separando por ciclo de ensino

# %%
censo_df[censo_df['month'] == '12'].groupby(['date'])[['mat_creche_tot', 'dem_creche_tot']].sum().plot.line()
plt.show()

# %%
censo_df[censo_df['month'] == '12'].groupby(['date'])[['mat_pre_tot', 'dem_pre_tot']].sum().plot.line()
plt.show()

# %% [markdown]
# ### Por Distrito

# %%
(pd.pivot_table(censo_df[censo_df['month'] == '12'], values='mat_creche_tot', index=['date'],
                     columns=['DISTRITO'], aggfunc=np.sum))
# Out:
# DISTRITO    AGUA RASA  ALTO DE PINHEIROS  ANHANGUERA  ARICANDUVA  ARTUR ALVIM  \
# date
# 2006-12-01      634.0              248.0       247.0       460.0        854.0
# 2007-12-01      723.0              290.0       325.0       552.0       1217.0
# 2008-12-01      770.0              257.0       684.0       715.0       1509.0
# 2009-12-01      732.0              280.0       817.0       878.0       1551.0
# 2010-12-01      685.0              259.0       877.0      1003.0       1646.0
# 2011-12-01      824.0              368.0      1095.0      1306.0       2115.0
# 2012-12-01      884.0              383.0      1316.0      1256.0       2232.0
# 2013-12-01      913.0              365.0      1244.0      1219.0       2161.0
# 2014-12-01      918.0              372.0      1711.0      1505.0       2166.0
# 2015-12-01      960.0              395.0      2622.0      1581.0       2334.0
# 2016-12-01     1053.0              399.0      2684.0      1520.0       2587.0
# 2017-12-01     1045.0              404.0      2668.0      1676.0       2685.0
#
# DISTRITO    BARRA FUNDA  BELA VISTA   BELEM  BOM RETIRO   BRAS     ...      \
# date                                                               ...
# 2006-12-01        259.0       605.0   201.0       472.0  307.0     ...
# 2007-12-01        237.0       599.0   437.0       511.0  317.0     ...
# 2008-12-01        341.0       649.0   534.0       504.0  442.0     ...
# 2009-12-01        287.0       755.0   635.0       489.0  398.0     ...
# 2010-12-01        284.0       852.0   663.0       505.0  405.0     ...
# 2011-12-01        375.0      1286.0   920.0       944.0  663.0     ...
# 2012-12-01        379.0      1461.0  1027.0       807.0  690.0     ...
# 2013-12-01        383.0      1322.0  1010.0       736.0  689.0     ...
# 2014-12-01        383.0      1298.0  1031.0       850.0  662.0     ...
# 2015-12-01        359.0      1420.0  1032.0       926.0  683.0     ...
# 2016-12-01        372.0      1491.0  1014.0       921.0  580.0     ...
# 2017-12-01        337.0      1509.0  1145.0       910.0  511.0     ...
#
# DISTRITO    VILA FORMOSA  VILA GUILHERME  VILA JACUI  VILA LEOPOLDINA  \
# date
# 2006-12-01         257.0           236.0      1145.0            215.0
# 2007-12-01         269.0           300.0      1320.0            212.0
# 2008-12-01         273.0           484.0      1951.0            259.0
# 2009-12-01         654.0           410.0      2115.0            268.0
# 2010-12-01         657.0           366.0      2346.0            228.0
# 2011-12-01        1208.0           728.0      3125.0            277.0
# 2012-12-01        1223.0           972.0      3324.0            266.0
# 2013-12-01        1288.0           881.0      3359.0            305.0
# 2014-12-01        1309.0           820.0      3499.0            403.0
# 2015-12-01        1567.0           931.0      3642.0            564.0
# 2016-12-01        1760.0           885.0      3945.0            607.0
# 2017-12-01        1691.0           933.0      4368.0            635.0
#
# DISTRITO    VILA MARIA  VILA MARIANA  VILA MATILDE  VILA MEDEIROS  \
# date
# 2006-12-01       912.0         296.0         356.0          777.0
# 2007-12-01      1141.0         357.0         684.0          905.0
# 2008-12-01      1515.0         317.0         903.0         1168.0
# 2009-12-01      1522.0         346.0         929.0         1578.0
# 2010-12-01      1494.0         385.0         910.0         1604.0
# 2011-12-01      2037.0         571.0        1126.0         2532.0
# 2012-12-01      2588.0         656.0        1242.0         2976.0
# 2013-12-01      2472.0         554.0        1193.0         2902.0
# 2014-12-01      2546.0         607.0        1483.0         2886.0
# 2015-12-01      2579.0         647.0        1555.0         3234.0
# 2016-12-01      2531.0         657.0        1836.0         3225.0
# 2017-12-01      3267.0         676.0        1885.0         3581.0
#
# DISTRITO    VILA PRUDENTE  VILA SONIA
# date
# 2006-12-01          832.0       525.0
# 2007-12-01         1043.0       760.0
# 2008-12-01         1306.0       848.0
# 2009-12-01         1289.0       839.0
# 2010-12-01         1254.0       833.0
# 2011-12-01         1656.0      1501.0
# 2012-12-01         1716.0      1582.0
# 2013-12-01         1760.0      1557.0
# 2014-12-01         1774.0      1621.0
# 2015-12-01         1844.0      2316.0
# 2016-12-01         2059.0      3005.0
# 2017-12-01         2340.0      3097.0
#
# [12 rows x 96 columns]

# %%
(pd.pivot_table(censo_df[(censo_df['month'] == '12') & (censo_df['DISTRITO'] == 'BRASILANDIA')], values='mat_creche_tot', index=['date'],
                     columns=['DISTRITO'], aggfunc=np.sum)).plot.line()

# %% [markdown]
# ### Diferença de matrículas de creche desde o começo da série, por distrito

# %%
max_date = censo_df[censo_df['month'] == '12']['date'].max()
min_date = censo_df[censo_df['month'] == '12']['date'].min()
min_mat_creche = censo_df[censo_df['date'] == min_date].groupby(['date'])[['mat_creche_tot']].sum()['mat_creche_tot'].iloc[0]
max_mat_creche = censo_df[censo_df['date'] == max_date].groupby(['date'])[['mat_creche_tot']].sum()['mat_creche_tot'].iloc[0]
max_mat_creche - min_mat_creche
# Out:
# 245840.0

# %%
# diferença absoluta
mat_creche_pivot_dist = (pd.pivot_table(censo_df[censo_df['month'] == '12'], values='mat_creche_tot', index=['date'],
                     columns=['DISTRITO'], aggfunc=np.sum))
mat_creche_pivot_dist = (mat_creche_pivot_dist.iloc[-1].subtract(mat_creche_pivot_dist.iloc[0])
    #.to_csv('mat_creche_pivot_dist.csv', header=True)
)

# %%
# diferença percentual
mat_creche_pivot_dist_pct = (pd.pivot_table(censo_df[censo_df['month'] == '12'], values='mat_creche_tot', index=['date'],
                     columns=['DISTRITO'], aggfunc=np.sum))
mat_creche_pivot_dist_pct = (mat_creche_pivot_dist_pct.iloc[-1].div(mat_creche_pivot_dist.iloc[0])
    #.to_csv('mat_creche_pivot_dist_pct.csv', header=True)
)
mat_creche_pivot_dist_pct
# Out:
# DISTRITO
# AGUA RASA              2.542579
# ALTO DE PINHEIROS      0.982968
# ANHANGUERA             6.491484
# ARICANDUVA             4.077859
# ARTUR ALVIM            6.532847
# BARRA FUNDA            0.819951
# BELA VISTA             3.671533
# BELEM                  2.785888
# BOM RETIRO             2.214112
# BRAS                   1.243309
# BRASILANDIA           29.389294
# BUTANTA                2.260341
# CACHOEIRINHA          13.192214
# CAMBUCI                1.160584
# CAMPO BELO             2.637470
# CAMPO GRANDE           4.031630
# CAMPO LIMPO           18.737226
# CANGAIBA              10.586375
# CAPAO REDONDO         22.895377
# CARRAO                 4.274939
# CASA VERDE             3.982968
# CIDADE ADEMAR         16.688564
# CIDADE DUTRA          17.160584
# CIDADE LIDER           9.233577
# CIDADE TIRADENTES     27.965937
# CONSOLACAO             0.510949
# CURSINO                3.306569
# ERMELINO MATARAZZO     9.092457
# FREGUESIA DO O         8.294404
# GRAJAU                33.080292
#                         ...
# REPUBLICA              0.077859
# RIO PEQUENO            7.819951
# SACOMA                18.844282
# SANTA CECILIA          3.742092
# SANTANA                3.072993
# SANTO AMARO            0.951338
# SAO DOMINGOS           4.226277
# SAO LUCAS              3.790754
# SAO MATEUS            12.321168
# SAO MIGUEL             6.476886
# SAO RAFAEL             9.788321
# SAPOPEMBA             17.771290
# SAUDE                  2.807786
# SE                     0.223844
# SOCORRO                1.328467
# TATUAPE                1.642336
# TREMEMBE              11.158151
# TUCURUVI               2.807786
# VILA ANDRADE           4.299270
# VILA CURUCA           13.014599
# VILA FORMOSA           4.114355
# VILA GUILHERME         2.270073
# VILA JACUI            10.627737
# VILA LEOPOLDINA        1.545012
# VILA MARIA             7.948905
# VILA MARIANA           1.644769
# VILA MATILDE           4.586375
# VILA MEDEIROS          8.712895
# VILA PRUDENTE          5.693431
# VILA SONIA             7.535280
# Name: 2017-12-01 00:00:00, Length: 96, dtype: float64

# %% [markdown]
# ### Comparando dez 2016 e dez 2017

# %%
# diferença absoluta
mat_creche_pivot_dist_diff = (pd.pivot_table(censo_df[censo_df['month'] == '12'], values='mat_creche_tot', index=['date'],
                     columns=['DISTRITO'], aggfunc=np.sum))
mat_creche_pivot_dist_diff = (mat_creche_pivot_dist_diff.iloc[-1].subtract(mat_creche_pivot_dist_diff.iloc[-2])
    #.to_csv('mat_creche_pivot_dist.csv', header=True)
)
mat_creche_pivot_dist_diff
# Out:
# DISTRITO
# AGUA RASA               -8.0
# ALTO DE PINHEIROS        5.0
# ANHANGUERA             -16.0
# ARICANDUVA             156.0
# ARTUR ALVIM             98.0
# BARRA FUNDA            -35.0
# BELA VISTA              18.0
# BELEM                  131.0
# BOM RETIRO             -11.0
# BRAS                   -69.0
# BRASILANDIA            857.0
# BUTANTA                280.0
# CACHOEIRINHA          1120.0
# CAMBUCI                 39.0
# CAMPO BELO              14.0
# CAMPO GRANDE           490.0
# CAMPO LIMPO            815.0
# CANGAIBA               345.0
# CAPAO REDONDO         1524.0
# CARRAO                -173.0
# CASA VERDE              79.0
# CIDADE ADEMAR         1136.0
# CIDADE DUTRA           538.0
# CIDADE LIDER            11.0
# CIDADE TIRADENTES      215.0
# CONSOLACAO               0.0
# CURSINO                126.0
# ERMELINO MATARAZZO     403.0
# FREGUESIA DO O         261.0
# GRAJAU                2370.0
#                        ...
# REPUBLICA               -3.0
# RIO PEQUENO            238.0
# SACOMA                 995.0
# SANTA CECILIA           37.0
# SANTANA                 49.0
# SANTO AMARO              0.0
# SAO DOMINGOS            69.0
# SAO LUCAS              -18.0
# SAO MATEUS            1007.0
# SAO MIGUEL              -1.0
# SAO RAFAEL             -20.0
# SAPOPEMBA              214.0
# SAUDE                   60.0
# SE                       0.0
# SOCORRO                 13.0
# TATUAPE                -57.0
# TREMEMBE               949.0
# TUCURUVI                21.0
# VILA ANDRADE           723.0
# VILA CURUCA            387.0
# VILA FORMOSA           -69.0
# VILA GUILHERME          48.0
# VILA JACUI             423.0
# VILA LEOPOLDINA         28.0
# VILA MARIA             736.0
# VILA MARIANA            19.0
# VILA MATILDE            49.0
# VILA MEDEIROS          356.0
# VILA PRUDENTE          281.0
# VILA SONIA              92.0
# Length: 96, dtype: float64

# %% [markdown]
# ### Mapas

# %%
sp_distritos = geojson.loads(open('dados/geosampa/distritos/sp_distritos.geojson').read())
print(f"{len(sp_distritos['features'])} distritos carregados")
# Out:
# 96 distritos carregados

# %%
mat_creche_pivot_dist_pct.get('PEDREIRA')
# Out:
# 9.4038929440389296

# %%
for i in sp_distritos['features']:
    distrito = i['properties']['ds_nome']
    i['properties']['mat_dif_pct'] = float(str(round(((mat_creche_pivot_dist_pct.get(distrito) - 1) * 100), 1)))
    i['properties']['mat_dif_abs'] = mat_creche_pivot_dist.get(distrito)

# %%
sp_distritos['features'][0]['properties']
# Out:
# {'area_m2': 13369947,
#  'ds_codigo': '51',
#  'ds_nome': 'MANDAQUI',
#  'mat_dif_abs': 1295.0,
#  'mat_dif_pct': 334.3}

# %%
with open('mapas/mat-creche-evolucao/sp_distritos.geojson', "w") as text_file:
    print(geojson.dumps(sp_distritos), file=text_file)

# %%
breaks = jenkspy.jenks_breaks(mat_creche_pivot_dist_pct, nb_class=5)
breaks
# Out:
# [0.07785888077858881,
#  4.586374695863747,
#  9.788321167883211,
#  13.94890510948905,
#  19.279805352798054,
#  33.08029197080292]

# %%
norm = matplotlib.colors.Normalize(vmin=breaks[0], vmax=breaks[-1], clip=True)
mapper = cm.ScalarMappable(norm=norm, cmap=cm.get_cmap('Blues'))

# %%
breaks_colors = []
for v in breaks:
    color = (matplotlib.colors.rgb2hex(mapper.to_rgba(v)))
    breaks_colors.append({'break': v, 'color': color})
    
breaks_colors
# Out:
# [{'break': 0.07785888077858881, 'color': '#f7fbff'},
#  {'break': 4.586374695863747, 'color': '#dceaf6'},
#  {'break': 9.788321167883211, 'color': '#b8d5ea'},
#  {'break': 13.94890510948905, 'color': '#8cc0dd'},
#  {'break': 19.279805352798054, 'color': '#519ccc'},
#  {'break': 33.08029197080292, 'color': '#08306b'}]

# %% [markdown]
# ### Ciclos

# %%
# comportamento cíclico da demanda

# %%
censo_df.groupby(['date'])[['dem_creche_tot']].sum().plot.line()
plt.show()

# %%
censo_df.groupby(['date'])[['dem_pre_tot']].sum().plot.line()
plt.show()
